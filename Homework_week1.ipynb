# %% [markdown]
# # Question 1

# %%
import numpy as np
np.__version__
# Out:
# '1.20.1'

# %%
import pandas as pd
columns=['Make','Model','Year','Engine Fuel Type','Engine HP','Engine Cylinders','Tansmission Type','Driven_Wheels','Number of Doors','Market Category','Vehicle Size','Vehicle Style','highway MPG','city mpg','Popularity','M']
data_frame=pd.read_csv("data.csv",names= columns)

# %% [markdown]
# # Question 2

# %%
data_frame.count()
# Out:
# Make                11915
# Model               11915
# Year                11915
# Engine Fuel Type    11912
# Engine HP           11846
# Engine Cylinders    11885
# Tansmission Type    11915
# Driven_Wheels       11915
# Number of Doors     11909
# Market Category      8173
# Vehicle Size        11915
# Vehicle Style       11915
# highway MPG         11915
# city mpg            11915
# Popularity          11915
# M                   11915
# dtype: int64

# %%
data_frame = data_frame.drop(data_frame.index[[0]])

data_frame
# Out:
#           Make       Model  Year                Engine Fuel Type Engine HP  \
# 1          BMW  1 Series M  2011     premium unleaded (required)       335
# 2          BMW    1 Series  2011     premium unleaded (required)       300
# 3          BMW    1 Series  2011     premium unleaded (required)       300
# 4          BMW    1 Series  2011     premium unleaded (required)       230
# 5          BMW    1 Series  2011     premium unleaded (required)       230
# ...        ...         ...   ...                             ...       ...
# 11910    Acura         ZDX  2012     premium unleaded (required)       300
# 11911    Acura         ZDX  2012     premium unleaded (required)       300
# 11912    Acura         ZDX  2012     premium unleaded (required)       300
# 11913    Acura         ZDX  2013  premium unleaded (recommended)       300
# 11914  Lincoln      Zephyr  2006                regular unleaded       221
#
# ...

# %%
len(data_frame.index)
# Out:
# 11914

# %% [markdown]
# # Question 3

# %%
df=data_frame.groupby('Make').count()
df = df.sort_values(by=['Model'], ascending=False)[:3]
df
# Out:
#             Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make
# Chevrolet    1123  1123              1123       1117              1121
# Ford          881   881               881        868               881
# Volkswagen    809   809               809        809               805
#
#             Tansmission Type  Driven_Wheels  Number of Doors  Market Category  \
# Make
# Chevrolet               1123           1123             1123              622
# Ford                     881            881              881              499
# Volkswagen               809            809              809              585
#
#             Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity  \
# Make
# Chevrolet           1123           1123         1123      1123        1123
# Ford                 881            881          881       881         881
# Volkswagen           809            809          809       809         809
#
#                M
# Make
# ...

# %% [markdown]
# # Question 4

# %%
rslt_df['Model'].unique()
# Out:
# array(['100', '200', '80', '90', 'A3', 'A4 allroad', 'A4', 'A5', 'A6',
#        'A7', 'A8', 'allroad quattro', 'allroad', 'Cabriolet', 'Coupe',
#        'Q3', 'Q5', 'Q7', 'R8', 'RS 4', 'RS 5', 'RS 6', 'RS 7', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S8', 'SQ5', 'TT RS', 'TT', 'TTS', 'V8'],
#       dtype=object)

# %%
df = pd.DataFrame(rslt_df['Model'].unique())
df
# Out:
#                   0
# 0               100
# 1               200
# 2                80
# 3                90
# 4                A3
# 5        A4 allroad
# 6                A4
# 7                A5
# 8                A6
# 9                A7
# 10               A8
# 11  allroad quattro
# 12          allroad
# 13        Cabriolet
# 14            Coupe
# 15               Q3
# 16               Q5
# 17               Q7
# 18               R8
# 19             RS 4
# 20             RS 5
# 21             RS 6
# 22             RS 7
# 23               S3
# 24               S4
# 25               S5
# 26               S6
# 27               S7
# 28               S8
# 29              SQ5
# 30            TT RS
# 31               TT
# 32              TTS
# 33               V8

# %%
df.count()
# Out:
# 0    34
# dtype: int64

# %% [markdown]
# # Question 5

# %%
data_frame.isnull().sum()>0
# Out:
# Make                False
# Model               False
# Year                False
# Engine Fuel Type     True
# Engine HP            True
# Engine Cylinders     True
# Tansmission Type    False
# Driven_Wheels       False
# Number of Doors      True
# Market Category      True
# Vehicle Size        False
# Vehicle Style       False
# highway MPG         False
# city mpg            False
# Popularity          False
# M                   False
# dtype: bool

# %% [markdown]
# # Question 6

# %%
data_frame['Engine Cylinders'].median()
# Out:
# 6.0

# %%
data_frame['Engine Cylinders'].mode()
# Out:
# 0    4
# dtype: object

# %%
data_frame['Engine Cylinders'].fillna(data_frame['Engine Cylinders'].mode())
# Out:
# 1        6
# 2        6
# 3        6
# 4        6
# 5        6
#         ..
# 11910    6
# 11911    6
# 11912    6
# 11913    6
# 11914    6
# Name: Engine Cylinders, Length: 11914, dtype: object

# %%
data_frame['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# # Question 7

# %% [markdown]
# # Select all the "Lotus" cars from the dataset.

# %%
lotus=data_frame[(data_frame['Make']=="Lotus")]

# %%
lotus
# Out:
#        Make      Model  Year                Engine Fuel Type Engine HP  \
# 3913  Lotus      Elise  2009     premium unleaded (required)       189
# 3914  Lotus      Elise  2009     premium unleaded (required)       218
# 3915  Lotus      Elise  2009     premium unleaded (required)       189
# 3916  Lotus      Elise  2010     premium unleaded (required)       189
# 3917  Lotus      Elise  2010     premium unleaded (required)       218
# 3918  Lotus      Elise  2011     premium unleaded (required)       189
# 3919  Lotus      Elise  2011     premium unleaded (required)       217
# 3920  Lotus      Elise  2011     premium unleaded (required)       217
# 4217  Lotus     Esprit  2002     premium unleaded (required)       350
# 4218  Lotus     Esprit  2003     premium unleaded (required)       350
# 4219  Lotus     Esprit  2004     premium unleaded (required)       350
# 4258  Lotus  Evora 400  2017     premium unleaded (required)       400
# ...

# %% [markdown]
# # Select only columns "Engine HP", "Engine Cylinders".

# %%
cols = ['Engine HP', 'Engine Cylinders']
df_subset=lotus.loc[:,cols]

# %% [markdown]
# # Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).

# %%
df_duplicates=df_subset.drop_duplicates()

# %%
df_duplicates
# Out:
#      Engine HP Engine Cylinders
# 3913       189                4
# 3914       218                4
# 3919       217                4
# 4217       350                8
# 4258       400                6
# 4260       276                6
# 4263       345                6
# 4293       257                4
# 4294       240                4

# %% [markdown]
# # Get the underlying NumPy array. Let's call it X.

# %%
df_duplicates['Engine HP'] = df_duplicates['Engine HP'].astype('float32')
df_duplicates['Engine Cylinders'] = df_duplicates['Engine Cylinders'].astype('float32')

X = df_duplicates.values
# Out:
# <ipython-input-111-c8576cef175d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_duplicates['Engine HP'] = df_duplicates['Engine HP'].astype('float32')
# <ipython-input-111-c8576cef175d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_duplicates['Engine Cylinders'] = df_duplicates['Engine Cylinders'].astype('float32')

# %%
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]], dtype=float32)

# %%
XT = X.T
XTX = XT.dot(X)

# %%
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]], dtype=float32)

# %%
IXTX = np.linalg.inv(XTrnasX)
print(np.linalg.inv(XTrnasX))
# Out:
# [[ 5.5308425e-05 -2.9431982e-03]
#  [-2.9431982e-03  1.6058844e-01]]

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])

# %%
IXTXXT=IXTX.dot(XT)
w = IXTXXT.dot(y)

# %%
w[0]
# Out:
# 4.594950191676617
